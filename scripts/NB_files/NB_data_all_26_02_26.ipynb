# %%
import sys
sys.path.insert(0, '../')
import data_generation_functions.SimulatorWaveEquation as simu
import numpy as np
from data_generation_functions import DataPlotter as dp
import matplotlib.pyplot as plt

# %% [markdown]
# ### This note book generates different data set using different initial values, locations of gaussian pulse, and ...
#
# Chosen fixed values:
# R = 10
# C = 1
# Lmax = ?
# tmax = ?
# generation = 5 # Level of refinement
#
# 1. Different location of Guassian pulse:
#     - (x0, y0, z0) are sampled from a gaussian distribution with midt (R,R,R)
#
# 2. Different heights and widths
#     -
# 3. Different start times
#
# 4. 2 different gaussian bumps interacting

# %% [markdown]
# 1. data generation

# %%
R = 1 # Radius
C = 1 # Wave speed
Lmax = 30 # Maximum degree of spherical harmonics
tmax = 5 # Maximum time  

omega_max = (C/R) * np.sqrt(Lmax*(Lmax+1))
T_min = 2*np.pi / omega_max
dt = T_min / 20
#dt = 0.01 
generations = 5 # level of refinement for the grid
center = np.array([0, -R, R])
center = R * center / np.linalg.norm(center)
x0, y0, z0 = center  # Initial position of the gaussian pulse
sigma_deg = 11 # Standard deviation of the Gaussian pulse in degrees
sigma = sigma_deg*np.pi/180 # Standard deviation of the Gaussian pulse in radians   
A = 1 # Amplitude of the Gaussian pulse

# Initial condition: Gaussian pulse centered at (x0, y0, z0)
def f_handle(x, y, z):
    # dot product with center
    dot = x*x0 + y*y0 + z*z0
    
    cos_alpha = np.clip(dot / R**2, -1.0, 1.0)

    alpha = np.arccos(cos_alpha)
     
    return A*np.exp(-(alpha**2) / (2*sigma**2))

# Initital condition: zero initial velocity
g_handle = lambda x, y, z: 0 * x

# %%
dt
# Out:
# np.float64(0.010301688138666264)

# %% [markdown]
# Simulate and save

# %%
sim = simu.SimulatorWaveEquation(R=1.0, C=C, Lmax=Lmax, tmax=tmax, f_handle=f_handle, g_handle=g_handle, generations=2, dt = 0.1)
print(sim.N)
# Out:
# 162

# %% [markdown]
# Lmax

# %%
L_needed = 1/sigma
L_needed
# Out:
# 5.208707228462029

# %% [markdown]
# L mesh

# %%
L_mesh = int(np.sqrt(sim.N / (4*np.pi)))
L_mesh
# Out:
# 3

# %% [markdown]
# Lmax found

# %%
Lmax_final = min(L_needed, L_mesh)
Lmax_final
# Out:
# 3

# %%
ds = sim.simulate(savedata=False,savegraph=False)  # (time, N)

# %%
def degree_spectrum(ulm):
    Lmax = ulm.shape[0] - 1
    spec = np.zeros(Lmax + 1)
    for ell in range(Lmax + 1):
        # valid m for this ell are -ell..ell, which correspond to columns (Lmax-ell):(Lmax+ell+1)
        col0 = Lmax - ell
        col1 = Lmax + ell+1 
        spec[ell] = np.sum(np.abs(ulm[ell, col0:col1])**2)
    return spec

# %%
coeffs = sim.get_spectral_coeffs(t=0.0)
ulm = coeffs["ulm"]

E = degree_spectrum(ulm) 
import matplotlib.pyplot as plt
plt.semilogy(E,'-o')   # avoid log(0)
plt.xlabel("$\ell$")
plt.ylabel("$\sum_m |u_{\ell m}|^2$")
plt.show()

# %%
dp = dp.DataPlotter(nc_path=None, ds=ds)
dp.animate_sphere(out_path="wave_equation_animation.gif")
